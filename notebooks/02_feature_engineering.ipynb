# %%
import pandas as pd
import numpy as np

# Read filtered CSV
df = pd.read_csv("../data/football_2023_2024_top5_clean.csv")

# %% [markdown]
# # Create Target Variable

# %%
# Create the target 
df["home_win"] = (df["home_goals"] > df["away_goals"]).astype(int)

# Verfies that home wins are created
print("Target distribution (counts):")
print(df["home_win"].value_counts())

print("\nTarget distribution (proportions):")
print(df["home_win"].value_counts(normalize=True).round(3))

# 3) Verify that more home goals results in home win
df[["League", "home_goals", "away_goals", "home_win"]].sample(10)
# Out:
# Target distribution (counts):
# home_win
# 0    847
# 1    637
# Name: count, dtype: int64
#
# Target distribution (proportions):
# home_win
# 0    0.571
# 1    0.429
# Name: proportion, dtype: float64
#               League  home_goals  away_goals  home_win
# 420          Ligue-1           1           0         1
# 475          Ligue-1           2           1         1
# 633   Premier-league           2           3         0
# 613          Ligue-1           1           2         0
# 530          Ligue-1           1           1         0
# 465          Ligue-1           4           0         1
# 1466          Laliga           0           3         0
# 971   Premier-league           1           2         0
# 675   Premier-league           6           0         1
# 1173         Serie-a           1           2         0
